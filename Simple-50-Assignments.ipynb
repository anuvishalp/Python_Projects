# %% [markdown]
# <a href="https://colab.research.google.com/github/anuvishalp/Python_Projects/blob/main/Simple-50-Assignments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## 50 assingments of python

# %%
## 1-5 questions of Python Basics

🌟 1 — Simple Variables (Coins Story)

              # Creating variables
              john = 10
              mary = 5
              adam = 6

              # Printing all variables on one line
              print(john, mary, adam)

              # Calculating total coins
              total_coins = john + mary + adam

              # Printing total coins
              print(total_coins)

✔ What this prints

10 5 6
21
-----------------------------
🚗 2 — Miles/Kilometers Conversion
You must fill only the ### parts.


        kilometers = 12.25
        miles = 7.38

        miles_to_kilometers = miles * 1.61
        kilometers_to_miles = kilometers / 1.61

        print(miles, "miles is", round(miles_to_kilometers, 2), "kilometers")
        print(kilometers, "kilometers is", round(kilometers_to_miles, 2), "miles")

✔ Example Output

7.38 miles is 11.88 kilometers
12.25 kilometers is 7.61 miles

-----------------------------

🧮 3 — Mini Calculator

            # input a float value for variable a here
            a = float(input("Enter value for a: "))

            # input a float value for variable b here
            b = float(input("Enter value for b: "))

            # output the result of addition here
            print("Addition:", a + b)

            # output the result of subtraction here
            print("Subtraction:", a - b)

            # output the result of multiplication here
            print("Multiplication:", a * b)

            # output the result of division here
            print("Division:", a / b)

            print("\nThat's all, users!")

-----------------------------

🌡 4 — Temperature Unit Converter (Celsius → Fahrenheit)

Formula:  f= 9/5*c+ 32

      celsius = float(input("Enter temperature in Celsius: "))

      fahrenheit = (9/5) * celsius + 32

      print("Temperature in Fahrenheit:", fahrenheit)
-----------------------------

⚖ 5 — BMI Calculator
Formula: BMI= weight/height^2

      weight = float(input("Enter your weight in kilograms: "))
      height = float(input("Enter your height in meters: "))

      bmi = weight / (height ** 2)

      print("Your BMI is:", bmi)

# %%
## 6-10 questions of Python

6 — Conditional Statements (Pass/Fail)

✔ Version 1 — Only IF
      score = int(input("Enter your score: "))

      if score > 40:
          print("You are passed")
✔ Version 2 — IF + ELSE

    score = int(input("Enter your score: "))

    if score > 40:
        print("You are passed")
    else:
        print("You are failed, better luck next time.")
--------------------------------------------
🅰️ 7 — Grading System
This one uses if / elif / else.

      score = int(input("Enter your score: "))

      if score < 0 or score > 100:
          print("Marks are out of range. Your score should be between 0 and 100.")
      elif score > 90:
          print("Grade: A")
      elif score > 80:
          print("Grade: B")
      elif score > 70:
          print("Grade: C")
      elif score > 60:
          print("Grade: D")
      else:
          print("Grade: E")

✔ Logic reminder
Python checks conditions top to bottom, so order matters.
--------------------------------------------
🔢 8 — Find Largest Number (3 Inputs)

      a = float(input("Enter first number: "))
      b = float(input("Enter second number: "))
      c = float(input("Enter third number: "))

      if a >= b and a >= c:
          print("Largest number is:", a)
      elif b >= a and b >= c:
          print("Largest number is:", b)
      else:
          print("Largest number is:", c)
✔ You can also use max(a, b, c) but your assignment wants logic practice.
--------------------------------------------
🔄 9 — Swapping Values (Without Third Variable)
This is a classic — and Python makes it easy.

✔ Pythonic way (best)

    x = int(input("Enter a number: "))
    y = int(input("Enter another number: "))

    x, y = y, x

    print("Values swapped!")
    print("x =", x)
    print("y =", y)

✔ Mathematical way (if you want to understand the logic)

    x = int(input("Enter a number: "))
    y = int(input("Enter another number: "))

    x = x + y
    y = x - y
    x = x - y

    print("Values swapped!")
    print("x =", x)
    print("y =", y)
--------------------------------------------
🔺 10 — Triangle Type Checker

      a = float(input("Enter side 1: "))
      b = float(input("Enter side 2: "))
      c = float(input("Enter side 3: "))

      if a == b == c:
          print("Equilateral triangle")
      elif a == b or b == c or a == c:
          print("Isosceles triangle")
      else:
          print("Scalene triangle")

# %%
## 11-20 Questions of python

⭐ 11 – Tax Calculator
      Rules Recap
      Income ≤ 300 → 0%

      400–700 → 10%

      700–1000 → 20%

      Above 1000 → 30%

✅ Python Program

                income = float(input("Enter your monthly income: "))

                if income <= 300:
                    tax = 0
                elif income <= 700:
                    tax = (income - 300) * 0.10
                elif income <= 1000:
                    tax = (400 * 0.10) + (income - 700) * 0.20
                else:
                    tax = (400 * 0.10) + (300 * 0.20) + (income - 1000) * 0.30

                print("Tax to pay is:", tax)
--------------------------------------
⭐ 12 – Factors from 1 to 10

      num = int(input("Enter a number: "))

      print("Factors from 1 to 10 are:")
      for i in range(1, 11):
          if num % i == 0:
              print(i)
--------------------------------------
⭐ 13 – For Loops
1. Print numbers 1 to 100
      for i in range(1, 101):
          print(i)
2. Print your name sentence 100 times
      for i in range(100):
          print("Anu is professional in Python")
--------------------------------------
⭐ 14 – Students List (20 names)

        students = []

        for i in range(20):
            name = input("Enter student name: ")
            students.append(name)
            print(students)
--------------------------------------
⭐ 15 – Average Marks of Class

        marks = []

        for i in range(20):
            m = float(input("Enter marks of student: "))
            marks.append(m)

        average = sum(marks) / len(marks)
        print("Average marks of class =", average)
--------------------------------------
⭐ 16 – Even or Odd (10 numbers)

        for i in range(10):
            num = int(input("Enter a number: "))
            if num % 2 == 0:
                print("Number is even!")
            else:
                print("Number is odd!")
--------------------------------------
⭐ 17 – Sum of List Manually

        li = [34, 54, 23, 5, 45, 65]

        total = 0

        for num in li:
            total += num
            print("Current sum:", total)

        print("Final sum =", total)
--------------------------------------
⭐ 18 – Multiplication Table

      num = int(input("Enter a number: "))

      for i in range(1, 11):
          print(num, "X", i, "=", num * i)
--------------------------------------
⭐ 19 – Student Names + Marks

        student_name = []
        student_marks = []

        for i in range(10):
            name = input("Enter student name: ")
            marks = int(input("Enter marks: "))
            student_name.append(name)
            student_marks.append(marks)

        for i in range(10):
            print(student_name[i], "got", student_marks[i], "marks")
--------------------------------------
⭐ 20 – Factorial Program (Completed Version)

product = 1
fact = int(input("Enter a number you want factorial of: "))

for i in range(1, fact + 1):
    product = product * i

print("Factorial of given number is:", product)
